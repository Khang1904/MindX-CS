# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Đọc dữ liệu và xem các đặc điểm của xe
df = pd.read_csv('cars.csv')
df.head()

# %%
print("Correlation between Miles and Model:", df['miles'].corr(df['Price']))
print("Correlation between Age and Model:", df['age'].corr(df['Price']))
print("Correlation between Year and Model:", df['year'].corr(df['Price']))
