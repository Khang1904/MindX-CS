# %% [markdown]
# # pandas 101

# %%
import pandas as pd

stats = pd.Series(
    {
        "Hoa": 37,
        "Nam": 48,
        "Hải": 42,
        "Linh": 39,
        "Nhân": 41,
        "Phương": 38,
        "Thu": 40,
        "Vũ": 40,
        "Bảo": 43,
    }
)

# %%
print(stats.mean)
print(stats.median)
print(stats.mode.iloc[0])
