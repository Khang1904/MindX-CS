# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

data = pd.read_csv("hw3_data.csv")

# %% [markdown]
# Câu hỏi 1:

# %%
print(len(data[data["Age"] > 30]))
# Out:
# 3

# %% [markdown]
# Câu hỏi 2:

# %%
print(sum(data["Salary"]))
# Out:
# 430000

# %% [markdown]
# Câu hỏi 3:

# %%
print(len(data[(data["Salary"] > 50000) & (data["Age"] < 40)]))
# Out:
# 4
